# %%
import pandas as pd

# %%
df_quote_member = pd.read_csv("uat_data/smartplus_quote_member.csv")
df_application = pd.read_csv("uat_data/smartplus_application.csv")

# %%
df_parties = pd.read_csv("uat_data/bronze/source_party.csv")
df_attributes = pd.read_csv("uat_data/bronze/raw_attribute.csv")
df_relationship = pd.read_csv("uat_data/bronze/relationship.csv")

# %%
df_parties
# Out:
#                   source_party_id          system_table_id  \
# 0          SP_SmartPlus_lead_L001       TBL_SMARTPLUS_LEAD
# 1          SP_SmartPlus_lead_L002       TBL_SMARTPLUS_LEAD
# 2          SP_SmartPlus_lead_L003       TBL_SMARTPLUS_LEAD
# 3          SP_SmartPlus_lead_L004       TBL_SMARTPLUS_LEAD
# 4         SP_SmartPlus_quote_Q001      TBL_SMARTPLUS_QUOTE
# ..                            ...                      ...
# 137  SP_Smile_policy_member_PM033  TBL_SMILE_POLICY_MEMBER
# 138  SP_Smile_policy_member_PM034  TBL_SMILE_POLICY_MEMBER
# 139  SP_Smile_policy_member_PM035  TBL_SMILE_POLICY_MEMBER
# 140  SP_Smile_policy_member_PM036  TBL_SMILE_POLICY_MEMBER
# 141          SP_Smile_claim_CL001          TBL_SMILE_CLAIM
#
#                         party_type_id source_record_id  \
# 0                   PT_SMARTPLUS_LEAD             L001
# 1                   PT_SMARTPLUS_LEAD             L002
# 2                   PT_SMARTPLUS_LEAD             L003
# ...

# %%
df_application
# Out:
#   app_id quote_id application_date    status contract_number  \
# 0   A001     Q001       2024-01-20  Approved            C001
# 1   A002     Q002       2024-02-10  Approved            C002
# 2   A003     Q003       2024-03-05  Approved            C003
# 3   A004     Q999       2024-05-01  Approved            C006
# 4   A005     Q010       2024-10-20  Approved            C011
# 5   A006      NaN       2025-01-01  Approved            C014
#
#   applicant_first_name applicant_last_name applicant_dob  \
# 0                 John               Smith    1985-06-15
# 1                Sarah                 Lee    1982-03-20
# 2                Alice                Wong    1988-04-15
# 3                Grace                Park    1990-09-25
# 4                Susan            Martinez    1987-02-18
# 5              Unknown              Person           NaN
#
#             applicant_email applicant_phone applicant_gov_id  \
# 0      john.smith@email.com  +852-9123-4567       A123456(7)
# ...

# %%
df_relationship
# Out:
#                                 party_relationship_id  \
# 0   REL_FK_SP_SmartPlus_quote_Q001_SP_SmartPlus_le...
# 1   REL_FK_SP_SmartPlus_quote_Q002_SP_SmartPlus_le...
# 2   REL_FK_SP_SmartPlus_quote_Q009_SP_SmartPlus_le...
# 3   REL_FK_SP_SmartPlus_quote_Q010_SP_SmartPlus_le...
# 4   REL_FK_SP_SmartPlus_quote_Q022_SP_SmartPlus_le...
# ..                                                ...
# 79  REL_FK_SP_SmartPlus_lead_L004_SP_SmartPlus_con...
# 80  REL_SR_SP_SmartPlus_application_A002_applicant...
# 81  REL_SR_SP_SmartPlus_application_A002_spouse_SP...
# 82  REL_SR_SP_SmartPlus_application_A003_applicant...
# 83  REL_SR_SP_SmartPlus_application_A003_spouse_SP...
#
#    metadata_relationship_id metadata_party_type_relationship_id  \
# 0            REL_QUOTE_LEAD                                 NaN
# 1            REL_QUOTE_LEAD                                 NaN
# 2            REL_QUOTE_LEAD                                 NaN
# ...
